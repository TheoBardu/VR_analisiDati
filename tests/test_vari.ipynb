# %%
import pandas as pd
from glob import glob
from numpy import arange
df = pd.read_excel('/Users/theo/Desktop/P.IVA/Aziende/Ermes/Lavori/RSPCT SRL/rev1/Rumore/misure/misA/730 A10570-26052601-104624.xlsx', sheet_name='Profilo storico')
df.iloc[:,1] = pd.to_datetime(df.iloc[:,1], format='%Y-%m-%d  %H:%M:%S', errors='coerce')
df.dropna(subset=df.columns[2],inplace=True) #tolgo tutte le righe che sono NaN nella colonna LAeq
# Out:
# 192

# %%
df
# df[df.columns[2]]
# Out:
#        Tipo di registrazione                 Data/Tempo                \
# 0                        Avvia                    2026-05-26 10:46:24
# 1                          NaN                    2026-05-26 10:46:25
# 2                          NaN                    2026-05-26 10:46:26
# 3                          NaN                    2026-05-26 10:46:27
# 4                          NaN                    2026-05-26 10:46:28
# ...                        ...                                    ...
# 1148                       NaN                    2026-05-26 11:05:32
# 1149                       NaN                    2026-05-26 11:05:33
# 1150                       NaN                    2026-05-26 11:05:34
# 1151                       NaN                    2026-05-26 11:05:35
# 1152                       NaN                    2026-05-26 11:05:36
#
#           LAeq          LCpk          LCeq          LASmax      \
# ...

# %%
files = glob('/Users/theo/Desktop/P.IVA/Aziende/Ermes/Lavori/RSPCT SRL/rev1/Rumore/misure/misA/*.xlsx')
files.sort()
files
# Out:
# ['/Users/theo/Desktop/P.IVA/Aziende/Ermes/Lavori/RSPCT SRL/rev1/Rumore/misure/misA/730 A10570-26052601-104624.xlsx',
#  '/Users/theo/Desktop/P.IVA/Aziende/Ermes/Lavori/RSPCT SRL/rev1/Rumore/misure/misA/730 A10570-26052602-111114.xlsx',
#  '/Users/theo/Desktop/P.IVA/Aziende/Ermes/Lavori/RSPCT SRL/rev1/Rumore/misure/misA/~$730 A10570-26052601-104624.xlsx']
